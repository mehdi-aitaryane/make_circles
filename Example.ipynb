# %%
from datasets import make_circles, print_shape, count_occurances
from plots import scatter2D, scatter3D

# %%
X, y = make_circles(n_samples=1000, n_features=2, n_circles=2, noise=0.0, random_state=2410, balanced=True)

# %%
print_shape(X, y)
# Out:
# X shape is  (1000, 2)
# y shape is  (1000,)

# %%
count_occurances(y)
# Out:
# class  0  has  499  items
# class  1  has  501  items

# %%
title = "2D Balanced Synthetic Circles Dataset"
xlabel = "Feature 1"
ylabel = "Feature 2"
scatter2D(title, xlabel, ylabel, X, y)

# %%
X, y = make_circles(n_samples=5500, n_features=2, n_circles=4, noise=0.0, random_state=111, balanced=False)

# %%
print_shape(X, y)
# Out:
# X shape is  (5500, 2)
# y shape is  (5500,)

# %%
count_occurances(y)
# Out:
# class  0  has  1693  items
# class  1  has  469  items
# class  2  has  1207  items
# class  3  has  2131  items

# %%
title = "2D Unbalanced Synthetic Circles Dataset"
xlabel = "Feature 1"
ylabel = "Feature 2"
scatter2D(title, xlabel, ylabel, X, y)

# %%
X, y = make_circles(n_samples=5500, n_features=2, n_circles=3, noise=1.0, random_state=68, balanced=False)

# %%
print_shape(X, y)
# Out:
# X shape is  (5500, 2)
# y shape is  (5500,)

# %%
count_occurances(y)
# Out:
# class  0  has  1651  items
# class  1  has  285  items
# class  2  has  3564  items

# %%
title = "2D Unbalanced Synthetic Circles Dataset With Noise"
xlabel = "Feature 1"
ylabel = "Feature 2"
scatter2D(title, xlabel, ylabel, X, y)

# %%
X, y = make_circles(n_samples=10000, n_features=3, n_circles=2, noise=0.0, random_state=2410, balanced=True)

# %%
print_shape(X, y)
# Out:
# X shape is  (10000, 3)
# y shape is  (10000,)

# %%
count_occurances(y)
# Out:
# class  0  has  5039  items
# class  1  has  4961  items

# %%
title = "3D Balanced Synthetic Circles Dataset"
xlabel = "Feature 1"
ylabel = "Feature 2"
zlabel = "Feature 3"
scatter3D(title, xlabel, ylabel, zlabel, X, y)

# %%
X, y = make_circles(n_samples=5500, n_features=3, n_circles=4, noise=0.0, random_state=111, balanced=False)

# %%
print_shape(X, y)
# Out:
# X shape is  (5500, 3)
# y shape is  (5500,)

# %%
count_occurances(y)
# Out:
# class  0  has  1693  items
# class  1  has  469  items
# class  2  has  1207  items
# class  3  has  2131  items

# %%
title = "3D Unbalanced Synthetic Circles Dataset"
xlabel = "Feature 1"
ylabel = "Feature 2"
zlabel = "Feature 3"
scatter3D(title, xlabel, ylabel, zlabel, X, y)

# %%
X, y = make_circles(n_samples=5500, n_features=3, n_circles=3, noise=1.0, random_state=68, balanced=False)

# %%
print_shape(X, y)
# Out:
# X shape is  (5500, 3)
# y shape is  (5500,)

# %%
count_occurances(y)
# Out:
# class  0  has  1651  items
# class  1  has  285  items
# class  2  has  3564  items

# %%
title = "3D Unbalanced Synthetic Circles Dataset With Noise"
xlabel = "Feature 1"
ylabel = "Feature 2"
zlabel = "Feature 3"
scatter3D(title, xlabel, ylabel, zlabel, X, y)
